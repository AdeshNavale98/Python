# %% [markdown]
# # Seaborns

# %%
import seaborn as sns

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
tips=sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %%
tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
type(tips['total_bill'])
# Out:
# pandas.core.series.Series

# %%
sns.distplot(tips['total_bill'])
# Out:
# C:\Users\Adesh\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
# kde-kernal Distribution

# %%
# !python --version
# Out:
# Python 3.8.5

# %%
sns.distplot(tips['total_bill'],kde=False)
# Out:
# C:\Users\Adesh\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.distplot(tips['total_bill'],kde=True,bins=244)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips['total_bill'],kde=True,bins=50)
# Out:
# C:\Users\Adesh\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips['total_bill'],kde=False,bins=244)
# Out:
# C:\Users\Adesh\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.jointplot(x='total_bill',y='tip',data=tips)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='resid')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde')

# %%
sns.kdeplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(tips)

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.pairplot(tips,hue='smoker')

# %%
sns.pairplot(tips,hue='smoker',palette='Set2')

# %%
sns.pairplot(tips,hue='sex',palette='rainbow')

# %%
sns.pairplot(tips,hue='time',palette='Set1')

# %%
sns.rugplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.kdeplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.rugplot(tips['total_bill'])
sns.kdeplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.rugplot(tips['tip'])
sns.kdeplot(tips['tip'])
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.histplot(x='time',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.barplot(x='time',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
sns.barplot(x='time',y='total_bill',data=tips,estimator=sum)
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=sum)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',data=tips,estimator=sum)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',hue='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='smoker',y='total_bill',hue='day',data=tips,palette='Set1')
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='total_bill'>

# %%
sns.barplot(x='smoker',y='total_bill',hue='day',data=tips,palette='Set1',estimator=sum)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='total_bill'>

# %%
sns.barplot(x='total_bill',y='smoker',hue='sex',data=tips,palette='Set1',estimator=sum)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='smoker'>

# %%
sns.barplot(x='size',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
sns.barplot(x='size',y='total_bill',hue='time',data=tips)
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
sns.barplot(x='size',y='total_bill',hue='time',data=tips,estimator=sum)
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
sns.barplot(x='size',y='total_bill',hue='time',data=tips,estimator=np.median)
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
sns.barplot(x='size',y='total_bill',hue='time',data=tips,estimator=np.std)
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
sns.barplot(x='time',y='tip',data=tips,order=['Lunch','Dinner'])
# Out:
# <AxesSubplot:xlabel='time', ylabel='tip'>

# %%
sns.barplot(x='time',y='tip',data=tips,order=['Lunch','Dinner'],palette='magma')
# Out:
# <AxesSubplot:xlabel='time', ylabel='tip'>

# %%
sns.countplot(x='smoker',data=tips)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='day',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.countplot(x='time',data=tips)
# Out:
# <AxesSubplot:xlabel='time', ylabel='count'>

# %%
sns.countplot(x='size',data=tips)
# Out:
# <AxesSubplot:xlabel='size', ylabel='count'>

# %%
sns.countplot(y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='count', ylabel='total_bill'>

# %%
sns.countplot(y='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='count', ylabel='sex'>

# %%
sns.countplot(y='day',data=tips)
# Out:
# <AxesSubplot:xlabel='count', ylabel='day'>

# %%
sns.countplot(x='size',data=tips)
# Out:
# <AxesSubplot:xlabel='size', ylabel='count'>

# %% [markdown]
# # Boxplot or Box and Whisker Plot

# %% [markdown]
# ### Boxplot Example

# %%
# Outlier - Extreme Value

# %%
sns.boxplot(x='day',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>
